# %% [markdown]
# ## Entendendo como extrair informações sobre repositórios no github
#
# [Search](https://developer.github.com/v3/search/)
# [Searching for repositories](https://help.github.com/en/articles/searching-for-repositories#search-by-repository-name-description-or-contents-of-the-readme-file)

# %% [markdown]
# ### Lista de qualifiers:  https://help.github.com/en/articles/searching-code
# ### Documentação para search: https://developer.github.com/v3/search/

# %%
import requests
import pandas

# %%
url = "https://api.github.com/search/repositories?q=data+science+language:python&sort=stars&order=desc"
url2 = url = "https://api.github.com/search/repositories?q=ciencia+de+dados+language:python&sort=stars&order=desc"

results = requests.get(url)

# %%
results.json()
# Out:
# {'incomplete_results': False,
#  'items': [{'archive_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/branches{/branch}',
#    'clone_url': 'https://github.com/ujjwalkarn/DataSciencePython.git',
#    'collaborators_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/ujjwalkarn/DataSciencePython/compare/{base}...{head}',
# ...

# %%
results.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 12 Jun 2019 20:03:08 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '10', 'X-RateLimit-Remaining': '9', 'X-RateLimit-Reset': '1560369848', 'Cache-Control': 'no-cache', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/search/repositories?q=datascience+language%3Apython&sort=stars&order=desc&page=2>; rel="next", <https://api.github.com/search/repositories?q=datascience+language%3Apython&sort=stars&order=desc&page=34>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Pr
# ...

# %%
data = dict(results.json())
data.keys()
# Out:
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
header = dict(results.links)
header.keys()
# Out:
# dict_keys(['next', 'last'])

# %%
data.get('total_count')
# Out:
# 2233

# %%
itens_por_pagina = len(data.get('items'))
itens_por_pagina
# Out:
# 30

# %%
total_paginas = data.get('total_count') // itens_por_pagina # opreração de div em python
total_paginas
# Out:
# 74

# %%
next_url = header.get('next').get('url')
# Out:
# 'https://api.github.com/search/repositories?q=datascience+language%3Apython&sort=stars&order=desc&page=2'

# %% [markdown]
# #### Alguns campos interessantes:
#
# name
# html_url
# description
# created_at
# updated_at
# pushed_at
# stargazers_count
# watchers_count
# language
# has_issues
# has_projects
# has_downloads
# has_wiki
# has_pages
# forks_count
# open_issues_count
# license
# forks
# open_issues
# watchers
#
# readme??
